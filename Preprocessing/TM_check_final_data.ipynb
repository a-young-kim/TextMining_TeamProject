# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/data/amazon_fashion_final.csv', index_col = 0)
df.head()
# Out:
#    overall  verified  reviewTime      reviewerID  \
# 0        1      True  2016-07-16   A6JFRI7IHQ4UH
# 1        1      True  2016-05-10  A2SAE2QVCE69B9
# 2        1      True  2016-04-26  A27F0VT6K7AMSH
# 3        1      True  2016-07-26  A3BSPW828VQ3VK
# 4        1      True  2016-09-04  A1J8SYC0N9050V
#
#                                           reviewText  year  \
# 0  Terrible , small , cheaply made, and even more...  2016
# 1       This product was made of poor quality items.  2016
# 2  Horrible shirt! It fits like a sack, the fabri...  2016
# 3                               Broke after 60 days.  2016
# 4                         Looks cheep. Poor quality.  2016
#
#                                                title
# 0  Sterling Silver Comedy Tragedy Mask Pendant Ne...
# 1  Rosemarie Collections Women's Take me to the B...
# 2  Very Cute Baby Lifter - Reps for Mom Funny Pre...
# 3  Couples Infinity Pendant Name Necklace in Ster...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165000 entries, 0 to 164999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   overall     165000 non-null  int64
#  1   verified    165000 non-null  bool
#  2   reviewTime  165000 non-null  object
#  3   reviewerID  165000 non-null  object
#  4   reviewText  165000 non-null  object
#  5   year        165000 non-null  int64
#  6   title       165000 non-null  object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 9.0+ MB

# %%
df = df.drop(['verified', 'reviewTime', 'reviewerID'], axis = 1)
df.head()
# Out:
#    overall                                         reviewText  year  \
# 0        1  Terrible , small , cheaply made, and even more...  2016
# 1        1       This product was made of poor quality items.  2016
# 2        1  Horrible shirt! It fits like a sack, the fabri...  2016
# 3        1                               Broke after 60 days.  2016
# 4        1                         Looks cheep. Poor quality.  2016
#
#                                                title
# 0  Sterling Silver Comedy Tragedy Mask Pendant Ne...
# 1  Rosemarie Collections Women's Take me to the B...
# 2  Very Cute Baby Lifter - Reps for Mom Funny Pre...
# 3  Couples Infinity Pendant Name Necklace in Ster...
# 4  Ularmo 2015 New Hot Fashion Women Bang Bang Mu...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df.groupby(df.overall).count().index, df.groupby(df.overall).count().year)
plt.show()

# %%
df.groupby(df.year).count()
# Out:
#       overall  reviewText   title
# year
# 2016   165000      165000  165000

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/content/drive/MyDrive/data/TM/Label/text_to_sentence_2_CatNotDone.csv')
df1.head()
# Out:
#    Unnamed: 0  column_num                                           sentence  \
# 0           0       22000    The material feels pretty cheap, not very soft.
# 1           1       22000  Colors and pattern are pretty but the material...
# 2           2       22001  I guess the "fits as described" reviews were p...
# 3           3       22001  Seller was also reluctant to refund due to "sh...
# 4           4       22001  Still too expensive for a shirt that may never...
#
#    index  overall  cat
# 0  22000        2    3
# 1  22000        2    2
# 2  22001        2    1
# 3  22001        2    0
# 4  22001        2    3

# %%
df1 = df1[['sentence', 'cat']]

# %%
df1.head()
# Out:
#                                             sentence  cat
# 0    The material feels pretty cheap, not very soft.    3
# 1  Colors and pattern are pretty but the material...    2
# 2  I guess the "fits as described" reviews were p...    1
# 3  Seller was also reluctant to refund due to "sh...    0
# 4  Still too expensive for a shirt that may never...    3

# %%
group_df1 = df1.groupby('cat').count()
plt.bar(group_df1.index, group_df1.sentence)
# Out:
# <BarContainer object of 5 artists>

# %%
group_df1.head()
# Out:
#      sentence
# cat
# -1         82
#  0          9
#  1        146
#  2         42
#  3        105

# %%
df2 = pd.read_csv('/content/drive/MyDrive/data/TM/Label/text_to_sentence_4_CatNotDone.csv')
df2.head()
# Out:
#    Unnamed: 0  column_num                                           sentence  \
# 0           0       66000                               Just wish she'd won.
# 1           1       66002  I like them but I ordered the wrong size and I...
# 2           2       66002                            So I had to return them
# 3           3       66003  Beautiful coat, just to small, the sizing deta...
# 4           4       66003                   even with the size chart is off.
#
#    index  overall  cat
# 0  66000        4   -1
# 1  66002        4    1
# 2  66002        4   -1
# 3  66003        4    1
# 4  66003        4    1

# %%
df2 = df2[['sentence', 'cat']]

# %%
df2.head()
# Out:
#                                             sentence  cat
# 0                               Just wish she'd won.   -1
# 1  I like them but I ordered the wrong size and I...    1
# 2                            So I had to return them   -1
# 3  Beautiful coat, just to small, the sizing deta...    1
# 4                   even with the size chart is off.    1

# %%
group_df2 = df2.groupby('cat').count()
plt.bar(group_df2.index, group_df2.sentence)
# Out:
# <BarContainer object of 4 artists>

# %%
group_df2.head()
# Out:
#      sentence
# cat
# -1         36
#  1         44
#  2         13
#  3         38

# %%
df = pd.concat([df1, df2])

# %%
df.head()
# Out:
#                                             sentence  cat
# 0    The material feels pretty cheap, not very soft.    3
# 1  Colors and pattern are pretty but the material...    2
# 2  I guess the "fits as described" reviews were p...    1
# 3  Seller was also reluctant to refund due to "sh...    0
# 4  Still too expensive for a shirt that may never...    3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515 entries, 0 to 130
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  515 non-null    object
#  1   cat       515 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 12.1+ KB

# %%
df = df[df.cat >= 0]

# %%
df.head()
# Out:
#                                             sentence  cat
# 0    The material feels pretty cheap, not very soft.    3
# 1  Colors and pattern are pretty but the material...    2
# 2  I guess the "fits as described" reviews were p...    1
# 3  Seller was also reluctant to refund due to "sh...    0
# 4  Still too expensive for a shirt that may never...    3

# %%
group_df = df.groupby('cat').count()
plt.bar(group_df.index, group_df.sentence)
# Out:
# <BarContainer object of 4 artists>

# %%
df.to_csv('/content/drive/MyDrive/data/TM/Label/label1.csv')
